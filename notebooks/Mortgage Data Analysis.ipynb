# %% [markdown]
# # Mortgage Data Analysis
# Notebook to analyze mortgage data.

# %%
import zipfile
from urllib.request import urlopen
import io

# %%
import pandas as pd

# %%
z = zipfile.ZipFile(io.BytesIO(urlopen('https://www.ffiec.gov/hmdarawdata/OTHER/2016HMDAInstitutionRecords.zip').read()))

# %%
f = z.open('2016HMDAInstitutionRecords.txt')

# %%
s = f.read().decode("utf-8")

# %%
type(s)
# Out:
# str

# %%
l = s.split('\n')

# %%
n = list(map(lambda x: x.count('\t'), l))

# %%
len(n)
# Out:
# 6763

# %%
l[2673].replace('\t\t', '\t')
# Out:
# '2016\t0000021122\t3\t36-2770692\tBRIDGEVIEW BANK GROUP\t7940 SOUTH HARLEM AVENUE\tBRIDGEVIEW\tIL\t60455-1500\tBRIDGEVIEW BANCORP, INC.\t7940 S. HARLEM AVE.\tBRIDGEVIEW\tIL\t60455-1500\tBRIDGEVIEW BK GRP\tBRIDGEVIEW\tIL\t1077735\t0\t9\t8377\tN\r'

# %%
ts = pd.read_csv(
    io.StringIO(s.replace('AVENUE\t\t', '\t')),
    header = None,
    delimiter = '\t')

# %%
ts.sort_values(20, ascending = False)
# Out:
#         0           1   2           3                               4   \
# 6670  2016  0000451965   9  94-1347393            WELLS FARGO BANK, NA
# 6031  2016  26-4599244   7  26-4599244              LOANDEPOT.COM, LLC
# 6433  2016  7197000003   7  38-2603955                   QUICKEN LOANS
# 6709  2016  0000852218   9  13-4994650         JPMORGAN CHASE BANK, NA
# 6745  2016  22-3039688   9  22-3039688    FREEDOM MORTGAGE CORPORATION
# 6679  2016  0000504713   9  31-0841368                   US BANK, N.A.
# 6483  2016  75-2921540   7  75-2921540             NATIONSTAR MORTGAGE
# 6673  2016  0000480228   9  57-0236115           BANK OF AMERICA, N.A.
# 6006  2016  26-2049351   7  26-2049351      PENNYMAC LOAN SERVICES LLC
# 5835  2016  13-6131491   7  13-6131491        CALIBER HOME LOANS, INC.
# 6690  2016  0000617677   9  53-0116705                            NFCU
# 6181  2016  41-1795868   7  41-1795868                DITECH FINANCIAL
# ...

# %%
lar = pd.read_csv(
    'https://www.ffiec.gov/hmdarawdata/LAR/MSA/2016/2016HMDALAR%20-%20MSAMD%2035614%20-%20NEW%20YORK-JERSEY%20CITY-WHITE%20PLAINS,%20NY-NJ.zip',
    header = None,
    compression = 'zip')
# Out:
# /home/gautam_sisodia/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (1,38,39,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(lar)
# Out:
# 357375
